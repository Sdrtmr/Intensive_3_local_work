# %% [markdown]
# ПОСТРОЕНИЕ ГРАФИКОВ

# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install statsmodels
# %pip install catboost
# %pip install openpyxl
# %pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in c:\users\user\appdata\roaming\python\python39\site-packages (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy<2,>=1.22.4; python_version < "3.11" in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: You are using pip version 20.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'c:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy in c:\users\user\appdata\roaming\python\python39\site-packages (1.26.2)
# WARNING: You are using pip version 20.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'c:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\user\appdata\roaming\python\python39\site-packages (3.9.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in c:\users\user\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib) (3.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'c:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'c:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: statsmodels in c:\users\user\appdata\roaming\python\python39\site-packages (0.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\user\appdata\roaming\python\python39\site-packages (from statsmodels) (1.26.2)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\user\appdata\roaming\python\python39\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: scipy>=1.3 in c:\users\user\appdata\roaming\python\python39\site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\user\appdata\roaming\python\python39\site-packages (from statsmodels) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas>=0.25->statsmodels) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas>=0.25->statsmodels) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.2->pandas>=0.25->statsmodels) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: catboost in c:\users\user\appdata\roaming\python\python39\site-packages (1.2.7)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from catboost) (1.26.2)
# Requirement already satisfied: scipy in c:\users\user\appdata\roaming\python\python39\site-packages (from catboost) (1.13.1)
# Requirement already satisfied: graphviz in c:\users\user\appdata\roaming\python\python39\site-packages (from catboost) (0.20.3)
# Requirement already satisfied: pandas>=0.24 in c:\users\user\appdata\roaming\python\python39\site-packages (from catboost) (2.1.3)
# Requirement already satisfied: matplotlib in c:\users\user\appdata\roaming\python\python39\site-packages (from catboost) (3.9.2)
# Requirement already satisfied: plotly in c:\users\user\appdata\roaming\python\python39\site-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in c:\users\user\appdata\roaming\python\python39\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (1.3.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (4.54.1)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (6.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in c:\users\user\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib->catboost) (3.18.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'c:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openpyxl in c:\users\user\appdata\roaming\python\python39\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\user\appdata\roaming\python\python39\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'c:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: scikit-learn in c:\users\user\appdata\roaming\python\python39\site-packages (1.6.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\user\appdata\roaming\python\python39\site-packages (from scikit-learn) (1.26.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from scikit-learn) (1.4.2)
# WARNING: You are using pip version 20.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the 'c:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ДАННЫЕ

# %%
import pandas as pd
test = pd.read_excel('test.xlsx')
train = pd.read_excel('train.xlsx')

# %% [markdown]
# TRAIN

# %%
from matplotlib import pyplot as plt

df1_1 = pd.read_excel('train.xlsx')

#Указание координат для построения графиков
x = df1_1['dt']
y = df1_1['Цена на арматуру']

plt.plot(x, y)
plt.show()

# %% [markdown]
# TEST

# %%
df1_2 = pd.read_excel('test.xlsx')

x = df1_2['dt']
y = df1_2['Цена на арматуру']

plt.plot(x, y)
plt.show()
